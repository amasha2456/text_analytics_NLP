# %%
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task3c-zeroshot
# !pip install -q transformers accelerate sentencepiece
# !python classify_zeroshot.py
# Out:
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 120 (delta 7), reused 23 (delta 4), pack-reused 94 (from 1)
# Receiving objects: 100% (120/120), 45.61 MiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (85/85), done.
# /content/text_analytics_NLP/task3c-zeroshot
# Device : 0
# PyTorch: 2.11.0+cu128
#
# Loading labeled corpus …
#   47,229 posts  |  10 categories
#   Labels: ['Education', 'Employment & Career', 'Finance, Banking & Telecoms', 'Help & General Q&A', 'Politics & National Affairs', 'Relationships & Social Life', 'Shopping & Local Recommendations', 'Sri Lanka Identity & Culture', 'Transport & Vehicles', 'Travel & Tourism']
#   Test set : 9,446 posts (same split as task3b)
#
# ══════════════════════════════════════════════════════════════
#   Zero-shot : facebook/bart-large-mnli
# ══════════════════════════════════════════════════════════════
# config.json: 100% 1.15k/1.15k [00:00<00:00, 4.26MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# model.safetensors: downloading bytes:   0% 518k/1.63G [00:00<42:35, 637kB/s]
# model.safetensors: downloading bytes:   1% 9.51M/1.63G [00:00<01:55, 14.0MB/s, 51.0kB/s  ]
# model.safetensors: downloading bytes:   1% 17.0M/1.63G [00:01<01:05, 24.7MB/s,  934kB/s  ]
# model.safetensors: downloading bytes:   2% 33.4M/1.63G [00:01<00:30, 52.6MB/s, 1.66MB/s  ]
# model.safetensors: downloading bytes:   3% 50.5M/1.63G [00:01<00:20, 78.8MB/s, 3.25MB/s  ]
# model.safetensors: downloading bytes:   7% 113M/1.63G [00:01<00:09, 166MB/s, 7.77MB/s  ]
# model.safetensors: downloading bytes:   8% 136M/1.63G [00:01<00:08, 180MB/s, 10.8MB/s  ]
# model.safetensors: downloading bytes:  11% 175M/1.63G [00:01<00:07, 184MB/s, 14.5MB/s  ]
# model.safetensors: downloading bytes:  13% 210M/1.63G [00:02<00:07, 179MB/s, 17.9MB/s  ]
# model.safetensors: downloading bytes:  15% 250M/1.63G [00:02<00:08, 161MB/s, 20.9MB/s  ]
# model.safetensors: downloading bytes:  17% 276M/1.63G [00:02<00:09, 148MB/s, 23.5MB/s  ]
# model.safetensors: downloading bytes:  20% 321M/1.63G [00:02<00:07, 176MB/s, 26.3MB/s  ]
# model.safetensors: downloading bytes:  28% 452M/1.63G [00:03<00:06, 178MB/s, 37.3MB/s  ]
# model.safetensors: downloading bytes:  29% 475M/1.63G [00:03<00:07, 154MB/s, 39.0MB/s  ]
# model.safetensors: downloading bytes:  66% 1.08G/1.63G [00:06<00:01, 276MB/s, 76.3MB/s  ]
# model.safetensors: reconstructing file:  46% 748M/1.63G [00:06<00:10, 82.4MB/s, 50.1MB/s  ]
# model.safetensors: reconstructing file:  50% 819M/1.63G [00:06<00:07, 106MB/s, 51.2MB/s  ]
# model.safetensors: reconstructing file:  56% 920M/1.63G [00:07<00:04, 144MB/s, 56.9MB/s  ]
# model.safetensors: reconstructing file:  62% 1.02G/1.63G [00:10<00:10, 58.3MB/s, 64.5MB/s  ]
# model.safetensors: reconstructing file:  68% 1.11G/1.63G [00:11<00:06, 78.1MB/s, 54.8MB/s  ]
# model.safetensors: reconstructing file:  74% 1.21G/1.63G [00:11<00:04, 98.4MB/s, 61.3MB/s  ]
# model.safetensors: reconstructing file:  80% 1.31G/1.63G [00:11<00:02, 130MB/s, 67.1MB/s  ]
# model.safetensors: reconstructing file:  85% 1.39G/1.63G [00:12<00:01, 152MB/s, 73.8MB/s  ]
# model.safetensors: downloading bytes: 100% 1.09G/1.09G [00:14<00:00, 72.8MB/s, 78.6MB/s  ]
# model.safetensors: reconstructing file: 100% 1.63G/1.63G [00:14<00:00, 109MB/s, 81.5MB/s  ]
# Loading weights: 100% 515/515 [00:00<00:00, 6412.30it/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 159kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 41.7MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 99.1MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 113MB/s]
#   Classifying test set … (this can take a while, no GPU shortcuts here)
#
#   Accuracy     : 0.2321
#   F1 (Weighted): 0.1989
#   F1 (Macro)   : 0.2310
#                                   precision    recall  f1-score   support
#
#                        Education       0.45      0.37      0.41       507
#              Employment & Career       0.43      0.32      0.37       517
#      Finance, Banking & Telecoms       0.69      0.02      0.04      1317
#               Help & General Q&A       0.15      0.81      0.26      1246
#      Politics & National Affairs       0.73      0.11      0.19       676
#      Relationships & Social Life       0.43      0.11      0.18      1011
# Shopping & Local Recommendations       0.35      0.07      0.12       739
#     Sri Lanka Identity & Culture       0.38      0.07      0.12      1909
#             Transport & Vehicles       0.29      0.34      0.31       335
#                 Travel & Tourism       0.41      0.26      0.32      1189
#
#                         accuracy                           0.23      9446
#                        macro avg       0.43      0.25      0.23      9446
#                     weighted avg       0.43      0.23      0.20      9446
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_bart_large_mnli.png
#
# ══════════════════════════════════════════════════════════════
#   Zero-shot : MoritzLaurer/deberta-v3-base-zeroshot-v1.1-all-33
# ══════════════════════════════════════════════════════════════
# config.json: 100% 1.02k/1.02k [00:00<00:00, 4.01MB/s]
#
# model.safetensors: downloading bytes:  95% 350M/369M [00:01<00:00, 379MB/s, 30.5MB/s  ]
# model.safetensors: downloading bytes: 100% 369M/369M [00:05<00:00, 68.5MB/s, 34.0MB/s  ]
# model.safetensors: reconstructing file: 100% 369M/369M [00:05<00:00, 68.5MB/s, 32.5MB/s  ]
# Loading weights: 100% 202/202 [00:00<00:00, 5640.17it/s]
# tokenizer_config.json: 100% 1.28k/1.28k [00:00<00:00, 5.33MB/s]
#
# spm.model: downloading bytes:   1% 32.8k/2.46M [00:00<00:47, 51.4kB/s]
# spm.model: downloading bytes: 100% 1.64M/1.64M [00:00<00:00, 2.39MB/s,  162kB/s  ]
# spm.model: reconstructing file: 100% 2.46M/2.46M [00:00<00:00, 3.59MB/s,  243kB/s  ]
# tokenizer.json: 100% 8.66M/8.66M [00:00<00:00, 109MB/s]
# added_tokens.json: 100% 23.0/23.0 [00:00<00:00, 167kB/s]
# special_tokens_map.json: 100% 286/286 [00:00<00:00, 445kB/s]
#   Classifying test set … (this can take a while, no GPU shortcuts here)
#
#   Accuracy     : 0.3621
#   F1 (Weighted): 0.3341
#   F1 (Macro)   : 0.3827
#                                   precision    recall  f1-score   support
#
#                        Education       0.44      0.90      0.59       507
#              Employment & Career       0.46      0.60      0.52       517
#      Finance, Banking & Telecoms       0.43      0.25      0.31      1317
#               Help & General Q&A       0.21      0.47      0.29      1246
#      Politics & National Affairs       0.40      0.43      0.41       676
#      Relationships & Social Life       0.46      0.34      0.39      1011
# Shopping & Local Recommendations       0.46      0.33      0.38       739
#     Sri Lanka Identity & Culture       0.47      0.05      0.09      1909
#             Transport & Vehicles       0.25      0.61      0.36       335
#                 Travel & Tourism       0.47      0.47      0.47      1189
#
#                         accuracy                           0.36      9446
#                        macro avg       0.41      0.45      0.38      9446
#                     weighted avg       0.41      0.36      0.33      9446
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_deberta_v3_zeroshot.png
#
# ══════════════════════════════════════════════════════════════
#   FINAL COMPARISON
# ══════════════════════════════════════════════════════════════
#   Model                         Accuracy    F1-Wt   F1-Mac
#   -----------------------------------------------------
#   bart-large-mnli                 0.2321   0.1989   0.2310
#   deberta-v3-zeroshot             0.3621   0.3341   0.3827
#
# Generating comparison plots …
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/01_model_comparison.png
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/02_per_class_f1.png
#
# ══════════════════════════════════════════════════════════════
#   Results → /content/text_analytics_NLP/task3c-zeroshot/results
#   Plots   → /content/text_analytics_NLP/task3c-zeroshot/plots
#   Task 3(c) complete ✓
# ══════════════════════════════════════════════════════════════

# %%
# %cd /content/text_analytics_NLP/task3c-zeroshot
# !ls results plots
# !zip -r results_and_plots_3c.zip results plots
from google.colab import files
files.download('results_and_plots_3c.zip')
# Out:
# /content/text_analytics_NLP/task3c-zeroshot
# plots:
# 01_model_comparison.png  cm_bart_large_mnli.png
# 02_per_class_f1.png	 cm_deberta_v3_zeroshot.png
#
# results:
# bart-large-mnli  comparison_report.txt	deberta-v3-zeroshot
#   adding: results/ (stored 0%)
#   adding: results/deberta-v3-zeroshot/ (stored 0%)
#   adding: results/deberta-v3-zeroshot/classification_report.txt (deflated 62%)
#   adding: results/deberta-v3-zeroshot/predictions.csv (deflated 69%)
#   adding: results/comparison_report.txt (deflated 74%)
#   adding: results/bart-large-mnli/ (stored 0%)
#   adding: results/bart-large-mnli/classification_report.txt (deflated 62%)
#   adding: results/bart-large-mnli/predictions.csv (deflated 69%)
#   adding: plots/ (stored 0%)
#   adding: plots/01_model_comparison.png (deflated 24%)
#   adding: plots/02_per_class_f1.png (deflated 20%)
#   adding: plots/cm_bart_large_mnli.png (deflated 14%)
#   adding: plots/cm_deberta_v3_zeroshot.png (deflated 13%)

# %%
# !ls /content
# Out:
# sample_data

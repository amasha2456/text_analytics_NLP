# %%
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task3c-zeroshot
# !python classify_decoder_llm.py
# Out:
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 173 (delta 22), reused 72 (delta 15), pack-reused 94 (from 1)
# Receiving objects: 100% (173/173), 48.28 MiB | 16.17 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Updating files: 100% (113/113), done.
# /content/text_analytics_NLP/task3c-zeroshot
# Device : 0
# PyTorch: 2.11.0+cu128
#
# Loading labeled corpus …
#   47,229 posts  |  10 categories
#   Train : 37,783  |  Test : 9,446 (same split as task3b/3c-NLI)
#   Eval subsample : 2,000 posts (stratified, for decoder-LLM prompting cost)
#
# ══════════════════════════════════════════════════════════════
#   Loading : Qwen/Qwen2.5-1.5B-Instruct
# ══════════════════════════════════════════════════════════════
# config.json: 100% 660/660 [00:00<00:00, 3.46MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# model.safetensors: downloading bytes:   0% 0.00/3.09G [00:00<?, ?B/s]
# model.safetensors: downloading bytes:   3% 97.7M/3.09G [00:02<00:32, 91.3MB/s, 5.56MB/s  ]
# model.safetensors: reconstructing file:   3% 78.9M/3.09G [00:02<01:17, 38.8MB/s, 4.13kB/s  ]
# model.safetensors: downloading bytes:   4% 139M/3.09G [00:02<00:24, 121MB/s, 10.9MB/s  ]
# model.safetensors: downloading bytes:   7% 218M/3.09G [00:03<00:17, 160MB/s, 16.9MB/s  ]
# model.safetensors: downloading bytes:   9% 270M/3.09G [00:03<00:14, 195MB/s, 21.4MB/s  ]
# model.safetensors: downloading bytes:  10% 313M/3.09G [00:03<00:13, 201MB/s, 25.9MB/s  ]
# model.safetensors: downloading bytes:  12% 385M/3.09G [00:03<00:12, 223MB/s, 30.6MB/s  ]
# model.safetensors: downloading bytes:  24% 756M/3.09G [00:05<00:06, 350MB/s, 59.4MB/s  ]
# model.safetensors: downloading bytes:  40% 1.23G/3.09G [00:06<00:05, 335MB/s, 90.7MB/s  ]
# model.safetensors: downloading bytes:  67% 2.06G/3.09G [00:09<00:03, 326MB/s,  137MB/s  ]
# model.safetensors: downloading bytes:  87% 2.69G/3.09G [00:11<00:01, 297MB/s,  163MB/s  ]
# model.safetensors: reconstructing file:  36% 1.12G/3.09G [00:13<00:25, 76.2MB/s, 61.2MB/s  ]
# model.safetensors: reconstructing file:  45% 1.40G/3.09G [00:13<00:14, 117MB/s, 60.1MB/s  ]
# model.safetensors: reconstructing file:  52% 1.61G/3.09G [00:14<00:10, 140MB/s, 79.0MB/s  ]
# model.safetensors: reconstructing file:  60% 1.87G/3.09G [00:17<00:10, 121MB/s, 90.3MB/s  ]
# model.safetensors: reconstructing file:  67% 2.06G/3.09G [00:17<00:06, 152MB/s, 93.1MB/s  ]
# model.safetensors: reconstructing file:  75% 2.33G/3.09G [00:18<00:04, 176MB/s,  105MB/s  ]
# model.safetensors: reconstructing file:  82% 2.53G/3.09G [00:21<00:04, 130MB/s,  117MB/s  ]
# model.safetensors: reconstructing file:  91% 2.80G/3.09G [00:22<00:01, 173MB/s,  111MB/s  ]
# model.safetensors: reconstructing file:  97% 2.99G/3.09G [00:22<00:00, 186MB/s,  126MB/s  ]
# model.safetensors: downloading bytes: 100% 2.69G/2.69G [00:23<00:00, 116MB/s,  163MB/s  ]
# model.safetensors: reconstructing file: 100% 3.09G/3.09G [00:23<00:00, 133MB/s,  137MB/s  ]
# Loading weights: 100% 338/338 [00:03<00:00, 92.98it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.28MB/s]
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 24.7MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 100MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 114MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 145MB/s]
#
#   ── qwen2.5-1.5b-instruct (zero-shot) ─────────────────
#   Generating …
#   Unparsed rate: 1.10%
#   Accuracy     : 0.1705
#   F1 (Weighted): 0.1741
#   F1 (Macro)   : 0.1858
#                                   precision    recall  f1-score   support
#
#                        Education       0.07      0.99      0.13       107
#              Employment & Career       0.44      0.10      0.16       109
#      Finance, Banking & Telecoms       0.36      0.23      0.28       279
#               Help & General Q&A       0.10      0.02      0.03       264
#      Politics & National Affairs       0.60      0.22      0.32       143
#      Relationships & Social Life       0.63      0.06      0.10       214
# Shopping & Local Recommendations       0.68      0.24      0.36       157
#     Sri Lanka Identity & Culture       1.00      0.00      0.00       404
#             Transport & Vehicles       0.30      0.04      0.07        71
#                 Travel & Tourism       0.68      0.28      0.40       252
#
#                        micro avg       0.17      0.17      0.17      2000
#                     accuracy                         0.17      2000
#                        macro avg       0.49      0.22      0.19      2000
#                     weighted avg       0.55      0.17      0.17      2000
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_qwen2.5_1.5b_instruct_(zero_shot).png
#
#   ── qwen2.5-1.5b-instruct (few-shot) ──────────────────
#   Generating …
#   Unparsed rate: 0.75%
#   Accuracy     : 0.2720
#   F1 (Weighted): 0.2558
#   F1 (Macro)   : 0.2669
#                                   precision    recall  f1-score   support
#
#                        Education       0.12      0.98      0.21       107
#              Employment & Career       0.43      0.08      0.14       109
#      Finance, Banking & Telecoms       0.44      0.25      0.32       279
#               Help & General Q&A       0.22      0.13      0.16       264
#      Politics & National Affairs       0.45      0.32      0.38       143
#      Relationships & Social Life       0.56      0.23      0.33       214
# Shopping & Local Recommendations       0.42      0.38      0.40       157
#     Sri Lanka Identity & Culture       1.00      0.01      0.02       404
#             Transport & Vehicles       0.15      0.24      0.18        71
#                 Travel & Tourism       0.47      0.59      0.52       252
#
#                        micro avg       0.27      0.27      0.27      2000
#                     accuracy                         0.27      2000
#                        macro avg       0.43      0.32      0.27      2000
#                     weighted avg       0.51      0.27      0.26      2000
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_qwen2.5_1.5b_instruct_(few_shot).png
#
# ══════════════════════════════════════════════════════════════
#   Loading : microsoft/Phi-3-mini-4k-instruct
# ══════════════════════════════════════════════════════════════
# config.json: 100% 967/967 [00:00<00:00, 6.01MB/s]
# model.safetensors.index.json: 100% 16.5k/16.5k [00:00<00:00, 12.0MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/2.67G [00:00<?, ?B/s]
# Downloading bytes:   6% 456M/7.64G [00:03<00:32, 220MB/s, 21.4MB/s  ]
# Downloading bytes:  15% 1.11G/7.64G [00:06<00:32, 202MB/s, 40.3MB/s  ]
# Downloading bytes:  21% 1.63G/7.64G [00:08<00:38, 157MB/s, 47.7MB/s  ]
# Downloading bytes:  24% 1.81G/7.64G [00:09<00:32, 181MB/s, 47.7MB/s  ]
# Downloading bytes:  33% 2.56G/7.64G [00:12<00:17, 292MB/s, 48.3MB/s  ]
# Downloading bytes:  35% 2.68G/7.64G [00:13<00:29, 166MB/s, 95.3MB/s  ]
# Downloading bytes:  36% 2.73G/7.64G [00:13<00:28, 175MB/s, 49.4MB/s  ]
# Downloading bytes:  37% 2.86G/7.64G [00:14<00:23, 204MB/s, 95.3MB/s  ]
# Downloading bytes:  48% 3.64G/7.64G [00:17<00:18, 219MB/s, 69.4MB/s  ]
# Downloading bytes:  54% 4.14G/7.64G [00:20<00:15, 227MB/s, 89.6MB/s  ]
# Downloading bytes:  57% 4.32G/7.64G [00:21<00:15, 211MB/s, 85.2MB/s  ]
# Downloading bytes:  59% 4.54G/7.64G [00:22<00:13, 225MB/s, 93.9MB/s  ]
# Downloading bytes:  61% 4.67G/7.64G [00:27<00:47, 62.3MB/s, 75.4MB/s  ]
# Downloading bytes:  72% 5.50G/7.64G [00:32<00:19, 107MB/s,  101MB/s  ]
# Downloading bytes:  73% 5.54G/7.64G [00:32<00:17, 118MB/s,  102MB/s  ]
# Downloading bytes:  73% 5.57G/7.64G [00:32<00:18, 114MB/s,  102MB/s  ]
# Downloading bytes:  86% 6.59G/7.64G [00:37<00:05, 208MB/s,  135MB/s  ]
# Reconstructing (incomplete total...):  76% 5.82G/7.64G [00:38<00:10, 178MB/s,  111MB/s  ]
# Downloading bytes:  86% 6.59G/7.64G [00:48<00:05, 208MB/s,  135MB/s  ]
# Reconstructing (incomplete total...):  85% 6.51G/7.64G [00:53<00:05, 203MB/s,  143MB/s  ]
# Reconstructing (incomplete total...):  95% 7.30G/7.64G [01:04<00:05, 68.5MB/s,  143MB/s  ]
# Reconstructing (incomplete total...): 100% 7.64G/7.64G [01:08<00:00, 70.6MB/s, 82.1MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:08<00:00, 34.23s/it]
# Download complete: 100% 6.59G/6.59G [01:08<00:00, 208MB/s,  135MB/s  ]
# Reconstruction complete: 100% 7.64G/7.64G [01:08<00:00, 112MB/s, 84.9MB/s  ]
# Download complete: 100% 6.59G/6.59G [01:08<00:00, 96.3MB/s,  135MB/s  ]
# Loading weights: 100% 195/195 [00:32<00:00,  6.01it/s]
# generation_config.json: 100% 181/181 [00:00<00:00, 1.25MB/s]
# tokenizer_config.json: 100% 3.44k/3.44k [00:00<00:00, 2.13MB/s]
# tokenizer.json: 100% 1.94M/1.94M [00:00<00:00, 107MB/s]
#
# tokenizer.model: downloading bytes:   0% 0.00/500k [00:00<?, ?B/s]
# tokenizer.model: downloading bytes: 100% 346k/346k [00:01<00:00, 242kB/s, 33.7kB/s  ]
# tokenizer.model: reconstructing file: 100% 500k/500k [00:01<00:00, 348kB/s, 48.5kB/s  ]
# added_tokens.json: 100% 306/306 [00:00<00:00, 1.99MB/s]
# special_tokens_map.json: 100% 599/599 [00:00<00:00, 4.13MB/s]
#
#   ── phi-3-mini-instruct (zero-shot) ───────────────────
#   Generating …
#   Unparsed rate: 0.15%
#   Accuracy     : 0.3375
#   F1 (Weighted): 0.3327
#   F1 (Macro)   : 0.3519
#                                   precision    recall  f1-score   support
#
#                        Education       0.46      0.60      0.52       107
#              Employment & Career       0.38      0.54      0.45       109
#      Finance, Banking & Telecoms       0.50      0.31      0.38       279
#               Help & General Q&A       0.21      0.18      0.20       264
#      Politics & National Affairs       0.22      0.61      0.32       143
#      Relationships & Social Life       0.52      0.23      0.32       214
# Shopping & Local Recommendations       0.24      0.66      0.35       157
#     Sri Lanka Identity & Culture       0.48      0.19      0.27       404
#             Transport & Vehicles       0.30      0.32      0.31        71
#                 Travel & Tourism       0.58      0.32      0.41       252
#
#                        micro avg       0.34      0.34      0.34      2000
#                     accuracy                         0.34      2000
#                        macro avg       0.39      0.40      0.35      2000
#                     weighted avg       0.41      0.34      0.33      2000
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_phi_3_mini_instruct_(zero_shot).png
#
#   ── phi-3-mini-instruct (few-shot) ────────────────────
#   Generating …
#   Unparsed rate: 1.30%
#   Accuracy     : 0.3460
#   F1 (Weighted): 0.3415
#   F1 (Macro)   : 0.3606
#                                   precision    recall  f1-score   support
#
#                        Education       0.41      0.43      0.42       107
#              Employment & Career       0.30      0.73      0.43       109
#      Finance, Banking & Telecoms       0.48      0.38      0.42       279
#               Help & General Q&A       0.17      0.23      0.20       264
#      Politics & National Affairs       0.28      0.57      0.38       143
#      Relationships & Social Life       0.50      0.29      0.37       214
# Shopping & Local Recommendations       0.31      0.52      0.39       157
#     Sri Lanka Identity & Culture       0.60      0.15      0.24       404
#             Transport & Vehicles       0.29      0.41      0.34        71
#                 Travel & Tourism       0.58      0.35      0.43       252
#
#                        micro avg       0.35      0.35      0.35      2000
#                     accuracy                         0.35      2000
#                        macro avg       0.39      0.41      0.36      2000
#                     weighted avg       0.43      0.35      0.34      2000
#
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/cm_phi_3_mini_instruct_(few_shot).png
#
# ══════════════════════════════════════════════════════════════
#   FINAL COMPARISON — Decoder-LLM Prompting (Task 3c)
# ══════════════════════════════════════════════════════════════
#   Run                                     Accuracy    F1-Wt   F1-Mac  Unparsed
#   ----------------------------------------------------------------------------
#   qwen2.5-1.5b-instruct (zero-shot)         0.1705   0.1741   0.1858     1.10%
#   qwen2.5-1.5b-instruct (few-shot)          0.2720   0.2558   0.2669     0.75%
#   phi-3-mini-instruct (zero-shot)           0.3375   0.3327   0.3519     0.15%
#   phi-3-mini-instruct (few-shot)            0.3460   0.3415   0.3606     1.30%
#
# Generating comparison plots …
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/03_decoder_llm_comparison.png
#   Plot → /content/text_analytics_NLP/task3c-zeroshot/plots/04_decoder_llm_per_class_f1.png
#
# ══════════════════════════════════════════════════════════════
#   Results → /content/text_analytics_NLP/task3c-zeroshot/results
#   Plots   → /content/text_analytics_NLP/task3c-zeroshot/plots
#   Task 3(c) decoder-LLM prompting complete ✓
# ══════════════════════════════════════════════════════════════

# %%
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task3b-transformers
# !pip install -q transformers accelerate seaborn
# Out:
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 103 (delta 1), reused 8 (delta 1), pack-reused 94 (from 1)
# Receiving objects: 100% (103/103), 45.59 MiB | 15.58 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Updating files: 100% (81/81), done.
# /content/text_analytics_NLP/task3b-transformers

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 494 bytes | 494.00 KiB/s, done.
# From https://github.com/amasha2456/text_analytics_NLP
#    f5d52aa..4821e1d  main       -> origin/main
# Updating f5d52aa..4821e1d
# Fast-forward
#  task3b-transformers/classify.py | 12 ++++++------
#  1 file changed, 6 insertions(+), 6 deletions(-)

# %%
# !python classify.py
# Out:
# Device : cuda
# PyTorch: 2.11.0+cu128
#
# Loading labeled corpus …
#   47,229 posts  |  10 categories
#   Labels: ['Education', 'Employment & Career', 'Finance, Banking & Telecoms', 'Help & General Q&A', 'Politics & National Affairs', 'Relationships & Social Life', 'Shopping & Local Recommendations', 'Sri Lanka Identity & Culture', 'Transport & Vehicles', 'Travel & Tourism']
#   Train : 37,783  |  Test : 9,446
#
# ══════════════════════════════════════════════════════════════
#   Fine-tuning : google-bert/bert-base-uncased
# ══════════════════════════════════════════════════════════════
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 5759.54it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: google-bert/bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# ...

# %%
# !zip -r results_and_plots.zip plots \
    results/label_map.json \
    results/comparison_report.txt \
    results/bert-base-uncased/classification_report.txt \
    results/bert-base-uncased/model \
    results/roberta-base/classification_report.txt \
    results/roberta-base/model

from google.colab import files
files.download('results_and_plots.zip')
# Out:
# updating: results/bert-base-uncased/classification_report.txt (deflated 64%)
# updating: results/bert-base-uncased/model/ (stored 0%)
# updating: results/bert-base-uncased/model/config.json (deflated 57%)
# updating: results/bert-base-uncased/model/model.safetensors (deflated 7%)
# updating: results/bert-base-uncased/model/tokenizer_config.json (deflated 43%)
# updating: results/bert-base-uncased/model/training_args.bin (deflated 53%)
# updating: results/bert-base-uncased/model/tokenizer.json (deflated 71%)
# updating: results/comparison_report.txt (deflated 75%)
# updating: results/label_map.json (deflated 35%)
# updating: results/roberta-base/classification_report.txt (deflated 63%)
# updating: results/roberta-base/model/ (stored 0%)
# updating: results/roberta-base/model/config.json (deflated 57%)
# updating: results/roberta-base/model/model.safetensors (deflated 10%)
# updating: results/roberta-base/model/tokenizer_config.json (deflated 51%)
# ...

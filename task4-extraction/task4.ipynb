# %%
# %cd /content
# !rm -rf text_analytics_NLP
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task4-extraction
# !nvidia-smi
# !python extract_llm.py
# Out:
# /content
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 216 (delta 41), reused 106 (delta 25), pack-reused 94 (from 1)
# Receiving objects: 100% (216/216), 49.61 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (133/133), done.
# /content/text_analytics_NLP/task4-extraction
# Sat Jul 18 12:47:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# ...

# %%
# !python build_ner_data.py
# Out:
# Using 489 successfully-parsed extractions as weak-label source
# Entity span-matching rate: 84.25% (615 matched, 115 unmatched)
# Posts with >=1 tagged entity: 277/489 (56.6%)
#
# Train: 392 posts → /content/text_analytics_NLP/task4-extraction/ner_data/train.jsonl
# Test  : 97 posts → /content/text_analytics_NLP/task4-extraction/ner_data/test.jsonl
# Tag vocab → /content/text_analytics_NLP/task4-extraction/ner_data/tag_vocab.json
# Task 4(b)(ii) NER data build complete ✓

# %%
# !python finetune_ner.py
# Out:
# Device : cuda
# PyTorch: 2.11.0+cu128
# Tag vocab: 15 tags, 7 entity types: ['COMPANY', 'EMPLOYMENT_TYPE', 'EXPERIENCE', 'JOB_TITLE', 'LOCATION', 'SALARY', 'SKILL']
# Train: 353  |  Val: 39  |  Test: 97
# ...
# config.json: 100% 570/570 [00:00<00:00, 2.33MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 234kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 15.8MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 55.9MB/s]
#
# model.safetensors: downloading bytes:  77% 338M/440M [00:01<00:00, 246MB/s, 30.3MB/s  ]
# model.safetensors: downloading bytes:  88% 389M/440M [00:01<00:00, 247MB/s, 33.7MB/s  ]
# model.safetensors: reconstructing file:  76% 335M/440M [00:02<00:00, 173MB/s, 25.7MB/s  ]
# model.safetensors: downloading bytes: 100% 415M/415M [00:02<00:00, 184MB/s, 37.4MB/s  ]
# model.safetensors: reconstructing file: 100% 440M/440M [00:02<00:00, 195MB/s, 40.8MB/s  ]
# Loading weights: 100% 197/197 [00:00<00:00, 4863.89it/s]
# ...

# %%
# !zip -r task4_results.zip results plots ner_data
from google.colab import files
files.download('task4_results.zip')
# Out:
# updating: results/ (stored 0%)
# updating: results/extractions.csv (deflated 78%)
# updating: results/extraction_report.txt (deflated 52%)
# updating: results/ner-bert-base-uncased/ (stored 0%)
# updating: results/ner-bert-base-uncased/classification_report.txt (deflated 57%)
# updating: results/ner-bert-base-uncased/model/ (stored 0%)
# updating: results/ner-bert-base-uncased/model/tokenizer_config.json (deflated 43%)
# updating: results/ner-bert-base-uncased/model/model.safetensors (deflated 7%)
# updating: results/ner-bert-base-uncased/model/tokenizer.json (deflated 71%)
# updating: results/ner-bert-base-uncased/model/config.json (deflated 59%)
# updating: results/ner-bert-base-uncased/model/training_args.bin (deflated 53%)
# updating: results/ner-bert-base-uncased/checkpoints/ (stored 0%)
# updating: results/ner-bert-base-uncased/checkpoints/checkpoint-270/ (stored 0%)
# updating: results/ner-bert-base-uncased/checkpoints/checkpoint-270/optimizer.pt (deflated 26%)
# ...

# %%
# !du -sh results
# !du -sh plots
# !du -sh ner_data
# !du -sh task4_results.zip
# Out:
# 13G	results
# 300K	plots
# 748K	ner_data
# 11G	task4_results.zip

# %%
# !ls -lh task4_results.zip
# Out:
# -rw-r--r-- 1 root root 11G Jul 18 14:57 task4_results.zip

# %%
from google.colab import files
files.download("task4_results.zip")

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp task4_results.zip /content/drive/MyDrive/
# Out:
# Mounted at /content/drive

# %%
# !cp task4_results.zip /content/drive/MyDrive/

# %%
# !ls -lh /content/drive/MyDrive/task4_results.zip
# Out:
# -rw------- 1 root root 11G Jul 18 15:41 /content/drive/MyDrive/task4_results.zip

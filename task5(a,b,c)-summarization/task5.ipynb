# %%
# %cd /content
# !rm -rf text_analytics_NLP
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task5-summarization
# !nvidia-smi
# !python summarize.py
# !python evaluate_summary.py
# Out:
# /content
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 250 (delta 51), reused 135 (delta 30), pack-reused 94 (from 1)
# Receiving objects: 100% (250/250), 50.08 MiB | 24.98 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Updating files: 100% (149/149), done.
# /content/text_analytics_NLP/task5-summarization
# Sat Jul 18 20:45:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Device : 0
# PyTorch: 2.11.0+cu128
# Loaded 489 successfully-parsed Employment & Career extractions
#
# Computing aggregate stats (pandas, not LLM-generated) …
# Total posts analyzed: 489
#
# Post intent breakdown:
#   - seeking_job: 54.6%
#   - other: 22.1%
#   - career_advice: 9.2%
#   - complaint: 9.0%
#   - salary_inquiry: 3.7%
#   - job_posting: 1.4%
#
# Most common employment types mentioned (when stated):
#   - internship: 29 posts
#   - part-time: 17 posts
#   - full-time: 16 posts
#   - remote: 8 posts
#   - freelance: 7 posts
#
# Top skills/tools mentioned: python (5), english (5), software engineering (5), project management (3), c# (3), html (3), css (3), teaching (3)
# Top locations mentioned: sri lanka (36), colombo (16), sl (7), kandy (4), japan (3), canada (2), dehiwala (2), australia (2)
#
# Salary explicitly mentioned in 6.3% of posts
# A specific company named in 15.1% of posts
# Only 1.4% of posts are actual job postings — 54.6% are people seeking jobs/advice instead
#
# Loading microsoft/Phi-3-mini-4k-instruct …
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 195/195 [00:31<00:00,  6.19it/s]
#
# MAP: 25 batches of up to 20 posts …
#     batch 4/25
#     batch 24/25
#
# REDUCE-1: 5 groups of up to 5 batch summaries …
#     group 4/5
#
# REDUCE-2: final multi-stakeholder summary …
#     final 1/1
#
# ============================================================
# ## Overview
# The analysis of r/srilanka job/career posts reveals a vibrant and diverse community engaged in discussions about career opportunities, challenges, and advice in Sri Lanka. The data shows a significant portion of the community is seeking job opportunities, with a smaller but notable interest in career advice, salary inquiries, and job postings. The community's concerns span various industries, from tech to custom jewelry, and include discussions on remote work, starting businesses, and navigating the job market as a transgender individual.
#
# ## For Job Seekers
# - **Research and apply to job postings**: With only 1.4% of posts being actual job postings, job seekers should actively look for and apply to these opportunities, as they represent a small but valuable chance to find employment.
# - **Seek advice on career transitions**: Given the high percentage of posts seeking career advice (54.6%), job seekers should engage with the community to gain insights into transitioning into new fields or roles.
# - **Consider remote work opportunities**: With a notable interest in remote work, especially in the tech industry, job seekers should explore and apply for remote positions that match their skills and interests.
#
# ## For Employers & Recruiters
# - **Post job opportunities**: To attract job seekers, employers and recruiters should increase the visibility of their job postings on r/srilanka, as there is a significant demand for job listings.
# - **Offer competitive salaries**: With 6.3% of posts explicitly mentioning salary, employers should ensure their compensation packages are competitive to attract top talent.
# - **Promote company culture and career advancement**: Employers should highlight their company culture and opportunities for career advancement in job postings to appeal to job seekers' interests in these areas.
#
# ## For Policymakers
# - **Address skills gaps**: The community's interest in various industries, including tech, software engineering, and custom jewelry, suggests a need for policies that support skill development and training in these sectors.
# - **Support youth employment**: Given the high percentage of job seekers, policymakers should focus on creating initiatives that support youth employment, including internships, apprenticeships, and remote work opportunities.
# - **Facilitate business startups**: With discussions on starting businesses, especially in custom jewelry, policymakers should consider creating a supportive environment for entrepreneurs, including access to capital, mentorship, and business development resources.
# ============================================================
#
# Results → /content/text_analytics_NLP/task5-summarization/results
# Task 5(a) summarization complete ✓
# Device : 0
# PyTorch: 2.11.0+cu128
#
# [1/2] Factual consistency check …
#   Numbers found in summary : 4
#   Flagged as unsupported   : 0
#   Consistency rate         : 1.0
#     1.4 -> OK
#     54.6 -> OK
#     6.3 -> OK
#     489 -> OK
#
# [2/2] LLM-as-judge scoring (Qwen/Qwen2.5-1.5B-Instruct) …
# config.json: 100% 660/660 [00:00<00:00, 3.28MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# model.safetensors: downloading bytes:   0% 0.00/3.09G [00:00<?, ?B/s]
# model.safetensors: downloading bytes:   2% 48.8M/3.09G [00:01<00:40, 74.2MB/s, 3.34MB/s  ]
# model.safetensors: downloading bytes:   2% 61.4M/3.09G [00:01<00:34, 86.8MB/s, 4.68MB/s  ]
# model.safetensors: reconstructing file:   1% 19.6M/3.09G [00:01<02:45, 18.5MB/s,  407kB/s  ]
# model.safetensors: reconstructing file:   2% 53.9M/3.09G [00:01<00:51, 59.5MB/s, 1.88MB/s  ]
# model.safetensors: downloading bytes:   4% 129M/3.09G [00:02<00:35, 83.6MB/s, 10.4MB/s  ]
# model.safetensors: downloading bytes:   6% 200M/3.09G [00:03<00:20, 138MB/s, 15.4MB/s  ]
# model.safetensors: downloading bytes:   8% 241M/3.09G [00:03<00:16, 173MB/s, 18.7MB/s  ]
# model.safetensors: downloading bytes:  10% 303M/3.09G [00:03<00:14, 190MB/s, 24.2MB/s  ]
# model.safetensors: reconstructing file:  10% 306M/3.09G [00:03<00:22, 126MB/s, 23.9MB/s  ]
# model.safetensors: downloading bytes:  16% 497M/3.09G [00:04<00:08, 294MB/s, 38.8MB/s  ]
# model.safetensors: downloading bytes:  17% 530M/3.09G [00:04<00:08, 301MB/s, 41.6MB/s  ]
# model.safetensors: downloading bytes:  35% 1.07G/3.09G [00:06<00:06, 334MB/s, 81.0MB/s  ]
# model.safetensors: reconstructing file:  14% 446M/3.09G [00:06<00:46, 57.2MB/s, 32.1MB/s  ]
# model.safetensors: downloading bytes:  39% 1.19G/3.09G [00:06<00:08, 226MB/s, 87.9MB/s  ]
# model.safetensors: downloading bytes:  45% 1.39G/3.09G [00:07<00:08, 192MB/s, 97.0MB/s  ]
# model.safetensors: downloading bytes:  68% 2.09G/3.09G [00:09<00:03, 307MB/s,  134MB/s  ]
# model.safetensors: downloading bytes:  73% 2.25G/3.09G [00:11<00:05, 147MB/s,  134MB/s  ]
# model.safetensors: downloading bytes:  87% 2.69G/3.09G [00:13<00:02, 161MB/s,  141MB/s  ]
# model.safetensors: reconstructing file:  51% 1.59G/3.09G [00:13<00:12, 120MB/s, 87.7MB/s  ]
# model.safetensors: reconstructing file:  60% 1.87G/3.09G [00:18<00:13, 90.0MB/s, 86.1MB/s  ]
# model.safetensors: reconstructing file:  67% 2.06G/3.09G [00:19<00:09, 105MB/s, 82.6MB/s  ]
# model.safetensors: reconstructing file:  75% 2.33G/3.09G [00:20<00:05, 132MB/s, 91.0MB/s  ]
# model.safetensors: reconstructing file:  82% 2.53G/3.09G [00:21<00:03, 151MB/s,  104MB/s  ]
# model.safetensors: reconstructing file:  91% 2.80G/3.09G [00:22<00:01, 174MB/s,  113MB/s  ]
# model.safetensors: reconstructing file:  97% 2.99G/3.09G [00:24<00:00, 142MB/s,  124MB/s  ]
# model.safetensors: downloading bytes: 100% 2.69G/2.69G [00:24<00:00, 108MB/s,  141MB/s  ]
# model.safetensors: reconstructing file: 100% 3.09G/3.09G [00:24<00:00, 124MB/s,  122MB/s  ]
# Loading weights: 100% 338/338 [00:04<00:00, 81.68it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 934kB/s]
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 18.5MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 62.3MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 114MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 115MB/s]
#   coherence                    4/5 — The report is well-organized and follows a logical structure, covering all key points related to job seekers, employers, and policymakers.
#   relevance                    4/5 — The report stays focused on jobs and careers in Sri Lanka without going off-topic, providing relevant information across different groups.
#   conciseness                  4/5 — The report is appropriately brief without unnecessary repetition, balancing detail with brevity effectively.
#   absence_of_hallucination     4/5 — The report avoids making confident claims that sound too specific or invented, maintaining an appropriate level of generality.
#
# Results → /content/text_analytics_NLP/task5-summarization/results
# Task 5(b) automated evaluation complete ✓

# %%
# !zip -r task5_results.zip results plots
from google.colab import files
files.download('task5_results.zip')
# Out:
#   adding: results/ (stored 0%)
#   adding: results/evaluation_report.json (deflated 70%)
#   adding: results/final_summary.md (deflated 56%)
#   adding: results/evaluation_report.txt (deflated 45%)
#   adding: results/batch_summaries.json (deflated 71%)
#   adding: results/aggregate_stats.json (deflated 66%)
#   adding: results/cluster_summaries.json (deflated 64%)
#   adding: plots/ (stored 0%)

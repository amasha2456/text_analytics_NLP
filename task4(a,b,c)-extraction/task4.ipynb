# %%
# %cd /content
# !rm -rf text_analytics_NLP
# !git clone https://github.com/amasha2456/text_analytics_NLP.git
# %cd text_analytics_NLP/task4-extraction
# !nvidia-smi
# !python extract_llm.py
# !python build_ner_data.py
# !python finetune_ner.py
# Out:
# /content
# Cloning into 'text_analytics_NLP'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 220 (delta 44), reused 109 (delta 27), pack-reused 94 (from 1)
# Receiving objects: 100% (220/220), 49.61 MiB | 11.60 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Updating files: 100% (133/133), done.
# /content/text_analytics_NLP/task4-extraction
# Sat Jul 18 19:39:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# ...

# %%
# !zip -r task4_results.zip \
    results/extractions.csv \
    results/extraction_report.txt \
    results/ner-bert-base-uncased/classification_report.txt \
    plots \
    ner_data
# !ls -lh task4_results.zip

from google.colab import drive
drive.mount('/content/drive')
# !cp task4_results.zip /content/drive/MyDrive/task4_results_small.zip
print("Saved to Drive as task4_results_small.zip")
# Out:
#   adding: results/extractions.csv (deflated 78%)
#   adding: results/extraction_report.txt (deflated 52%)
#   adding: results/ner-bert-base-uncased/classification_report.txt (deflated 57%)
#   adding: plots/ (stored 0%)
#   adding: plots/04_ner_per_entity_f1.png (deflated 25%)
#   adding: plots/01_field_fill_rates.png (deflated 25%)
#   adding: plots/03_post_intent_distribution.png (deflated 20%)
#   adding: plots/02_groundedness_by_field.png (deflated 24%)
#   adding: plots/05_ner_training_history.png (deflated 13%)
#   adding: ner_data/ (stored 0%)
#   adding: ner_data/test.jsonl (deflated 83%)
#   adding: ner_data/tag_vocab.json (deflated 53%)
#   adding: ner_data/train.jsonl (deflated 84%)
#   adding: ner_data/build_report.txt (deflated 43%)
# -rw-r--r-- 1 root root 453K Jul 18 20:26 task4_results.zip
# Mounted at /content/drive
# Saved to Drive as task4_results_small.zip
